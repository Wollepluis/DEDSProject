# %% [markdown]
# # Database Details

# %%
# SQLite
sqlite_path = "Data/aenc.sqlite"

#AdventureWorks
adventureworks_path = "Data/AdventureWorks.mdb"

# NorthWind
northwind_user = "sa"
northwind_password = "MelleWessel123"
northwind_host = "localhost"
northwind_port = "1433"
northwind_dbname = "master"

# PostgreSQL
pg_user = "admin"
pg_password = "MelleWessel123"
pg_host = "132.164.25.250"
pg_port = "5432"
pg_dbname = "test_db"

# %% [markdown]
# # Reading the SQLite database

# %%
import sqlite3
import pandas as pd

connection = sqlite3.connect(sqlite_path)

Bonus_AenC = pd.read_sql("SELECT * FROM Bonus", connection)
Customer_AenC = pd.read_sql("SELECT * FROM Customer", connection)
Department_AenC = pd.read_sql("SELECT * FROM Department", connection)
Employee_AenC = pd.read_sql("SELECT * FROM Employee", connection)
Product_AenC = pd.read_sql("SELECT * FROM Product", connection)
Sales_Order_AenC = pd.read_sql("SELECT * FROM Sales_Order", connection)
Sales_Order_Item_AenC = pd.read_sql("SELECT * FROM Sales_Order_Item", connection)
State_AenC = pd.read_sql("SELECT * FROM State", connection)

# %% [markdown]
# ### Printing the tables

# %%
print("Bonus_AenC")
print(Bonus_AenC.head(5))

print("\n\nCustomer_AenC")
print(Customer_AenC.head(5))

print("\n\nDepartment_AenC")
print(Department_AenC.head(5))

print("\n\nEmployee_AenC")
print(Employee_AenC.head(5))

print("\n\nProduct_AenC")
print(Product_AenC.head(5))

print("\n\nSales_Order_AenC")
print(Sales_Order_AenC.head(5))

print("\n\nSales_Order_Item_AenC")
print(Sales_Order_Item_AenC.head(5))

print("\n\nState_AenC")
print(State_AenC.head(5))
# Out:
# Bonus_AenC
#    emp_id bonus_date  bonus_amount
# 0     129  31-dec-24            50
# 1     195  31-dec-23            50
# 2     299  31-dec-23           200
# 3    1142  31-dec-23           100
# 4     129  31-dec-22            50
#
#
# Customer_AenC
#     id     fname         lname                 address        city state  \
# 0  101  Michaels        Devlin     3114 Pioneer Avenue  Rutherford    NJ
# 1  102      Beth        Reiser      1033 Whippany Road    New York    NY
# 2  103      Erin  Niedringhaus     1990 Windsor Street       Paoli    PA
# 3  104    Meghan         Mason  550 Dundas Street East   Knoxville    TN
# 4  105     Laura      McCarthy         1210 Highway 36      Carmel    IN
#
#      zip       phone        company_name
# 0  07070  2015558966     The Power Group
# 1  10154  2125558725           AMF Corp.
# 2  19301  2155556513  Darling Associates
# 3  37919  6155555463              P.S.C.
# 4  46032  3175558437          Amo & Sons
#
#
# Department_AenC
# ...

# %% [markdown]
# # Reading the AdventureWorks database

# %%
import subprocess
import pandas as pd
import io

tables = subprocess.run(["mdb-tables", adventureworks_path], capture_output=True, text=True).stdout.split()

dataframes = {}

for table in tables:
    result = subprocess.run(["mdb-export", adventureworks_path, table], capture_output=True)
    output_text = result.stdout.decode("latin1")
    df = pd.read_csv(io.StringIO(output_text))
    dataframes[table] = df



HumanResourcesDepartment_AdventureWorks = dataframes["HumanResources_Department"]
HumanResourcesEmployee_AdventureWorks = dataframes["HumanResources_Employee"]
PersonAddress_AdventureWorks = dataframes["Person_Address"]
Person_AdventureWorks = dataframes["Person_Person"]
ProductionBillOfMaterials_AdventureWorks = dataframes["Production_BillOfMaterials"]
Product_AdventureWorks = dataframes["Production_Product"]
ProductCategory_AdventureWorks = dataframes["Production_ProductCategory"]
PurchaseOrderDetail_AdventureWorks = dataframes["Purchasing_PurchaseOrderDetail"]
PurchaseOrderHeader_AdventureWorks = dataframes["Purchasing_PurchaseOrderHeader"]
Vendor_AdventureWorks = dataframes["Purchasing_Vendor"]
Customer_AdventureWorks = dataframes["Sales_Customer"]
SalesOrderDetail_AdventureWorks = dataframes["Sales_SalesOrderDetail"]
SalesOrderHeader_AdventureWorks = dataframes["Sales_SalesOrderHeader"]
SalesTerritory_AdventureWorks = dataframes["Sales_SalesTerritory"]
Store_AdventureWorks = dataframes["Sales_Store"]
Sysdiagrams_AdventureWorks = dataframes["sysdiagrams"]

SalesOrderHeader_AdventureWorks
# Out:
#        SalesOrderID  RevisionNumber          OrderDate            DueDate  \
# 0             43659               8  05/31/21 00:00:00  06/12/21 00:00:00
# 1             43660               8  05/31/21 00:00:00  06/12/21 00:00:00
# 2             43661               8  05/31/21 00:00:00  06/12/21 00:00:00
# 3             43662               8  05/31/21 00:00:00  06/12/21 00:00:00
# 4             43663               8  05/31/21 00:00:00  06/12/21 00:00:00
# ...             ...             ...                ...                ...
# 31460         75119               8  06/30/24 00:00:00  07/12/24 00:00:00
# 31461         75120               8  06/30/24 00:00:00  07/12/24 00:00:00
# 31462         75121               8  06/30/24 00:00:00  07/12/24 00:00:00
# 31463         75122               8  06/30/24 00:00:00  07/12/24 00:00:00
# 31464         75123               8  06/30/24 00:00:00  07/12/24 00:00:00
#
#                 ShipDate  Status  OnlineOrderFlag SalesOrderNumber  \
# ...

# %% [markdown]
# ### Printing the tables

# %%
print("HumanResources_Department")
print(HumanResourcesDepartment_AdventureWorks.head(5))

print("\n\nHumanResources_Employee")
print(HumanResourcesEmployee_AdventureWorks.head(5))

print("\n\nPerson_Address")
print(PersonAddress_AdventureWorks.head(5))

print("\n\nPerson_Person")
print(Person_AdventureWorks.head(5))

print("\n\nProduction_BillOfMaterials")
print(ProductionBillOfMaterials_AdventureWorks.head(5))

print("\n\nProduction_Product")
print(Product_AdventureWorks.head(5))

print("\n\nProduction_ProductCategory")
print(ProductCategory_AdventureWorks.head(5))

print("\n\nPurchasing_PurchaseOrderDetail")
print(PurchaseOrderDetail_AdventureWorks.head(5))

print("\n\nPurchasing_PurchaseOrderHeader")
print(PurchaseOrderHeader_AdventureWorks.head(5))

print("\n\nPurchasing_Vendor")
print(Vendor_AdventureWorks.head(5))

print("\n\nSales_Customer")
print(Customer_AdventureWorks.head(5))

print("\n\nSales_SalesOrderDetail")
print(SalesOrderDetail_AdventureWorks.head(5))

print("\n\nSales_SalesOrderHeader")
print(SalesOrderHeader_AdventureWorks.head(5))

print("\n\nSales_SalesTerritory")
print(SalesTerritory_AdventureWorks.head(5))

print("\n\nSales_Store")
print(Store_AdventureWorks.head(5))

print("\n\nsysdiagrams")
print(Sysdiagrams_AdventureWorks.head(5))
# Out:
# HumanResources_Department
#    DepartmentID         Name                 GroupName       ModifiedDate
# 0             1  Engineering  Research and Development  04/30/18 00:00:00
# 1             2  Tool Design  Research and Development  04/30/18 00:00:00
# 2             3        Sales       Sales and Marketing  04/30/18 00:00:00
# 3             4    Marketing       Sales and Marketing  04/30/18 00:00:00
# 4             5   Purchasing      Inventory Management  04/30/18 00:00:00
#
#
# HumanResources_Employee
#    BusinessEntityID  NationalIDNumber                   LoginID  \
# 0                 1         295847284      adventure-works\ken0
# 1                 2         245797967    adventure-works\terri0
# 2                 3         509647174  adventure-works\roberto0
# 3                 4         112457891      adventure-works\rob0
# 4                 5         695256908     adventure-works\gail0
#
#   OrganizationNode  OrganizationLevel                       JobTitle  \
# ...

# %% [markdown]
# # Reading the NorthWind database

# %%
from sqlalchemy import create_engine

northwind_conn_str = f"mssql+pyodbc://{northwind_user}:{northwind_password}@{northwind_host}:{northwind_port}/{northwind_dbname}?driver=ODBC+Driver+17+for+SQL+Server"

engine = create_engine(northwind_conn_str)

Categories_NorthWind = pd.read_sql("SELECT * FROM Categories", engine)
CustomerCustomerDemo_NorthWind = pd.read_sql("SELECT * FROM CustomerCustomerDemo", engine)
CustomerDemographics_NorthWind = pd.read_sql("SELECT * FROM CustomerDemographics", engine)
Customers_NorthWind = pd.read_sql("SELECT * FROM Customers", engine)
EmployeeTerritories_NorthWind = pd.read_sql("SELECT * FROM EmployeeTerritories", engine)
Employees_NorthWind = pd.read_sql("SELECT * FROM Employees", engine)
OrderDetails_NorthWind = pd.read_sql("SELECT * FROM [Order Details]", engine)
Orders_NorthWind = pd.read_sql("SELECT * FROM Orders", engine)
Products_NorthWind = pd.read_sql("SELECT * FROM Products", engine)
Region_NorthWind = pd.read_sql("SELECT * FROM Region", engine)
Shippers_NorthWind = pd.read_sql("SELECT * FROM Shippers", engine)
Suppliers_NorthWind = pd.read_sql("SELECT * FROM Suppliers", engine)
Territories_NorthWind = pd.read_sql("SELECT * FROM Territories", engine)

# %% [markdown]
# ### Printing the tables

# %%
print("Categories_NorthWind")
print(Categories_NorthWind.head(5))

print("\n\nCustomerCustomerDemo_NorthWind")
print(CustomerCustomerDemo_NorthWind.head(5))

print("\n\nCustomerDemographics_NorthWind")
print(CustomerDemographics_NorthWind.head(5))

print("\n\nCustomers_NorthWind")
print(Customers_NorthWind.head(5))

print("\n\nEmployeeTerritories_NorthWind")
print(EmployeeTerritories_NorthWind.head(5))

print("\n\nEmployees_NorthWind")
print(Employees_NorthWind.head(5))

print("\n\nOrderDetails_NorthWind")
print(OrderDetails_NorthWind.head(5))

print("\n\nOrders_NorthWind")
print(Orders_NorthWind.head(5))

print("\n\nProducts_NorthWind")
print(Products_NorthWind.head(5))

print("\n\nRegion_NorthWind")
print(Region_NorthWind.head(5))

print("\n\nShippers_NorthWind")
print(Shippers_NorthWind.head(5))

print("\n\nSuppliers_NorthWind")
print(Suppliers_NorthWind.head(5))

print("\n\nTerritories_NorthWind")
print(Territories_NorthWind.head(5))
# Out:
# Categories_NorthWind
# Empty DataFrame
# Columns: [CategoryID, CategoryName, Description, Picture]
# Index: []
#
#
# CustomerCustomerDemo_NorthWind
# Empty DataFrame
# Columns: [CustomerID, CustomerTypeID]
# Index: []
#
#
# CustomerDemographics_NorthWind
# Empty DataFrame
# Columns: [CustomerTypeID, CustomerDesc]
# Index: []
#
#
# Customers_NorthWind
#   CustomerID                         CompanyName         ContactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
#
#            ContactTitle                        Address         City Region  \
# 0  Sales Representative                  Obere Str. 57       Berlin   None
# ...

# %% [markdown]
# # Normalizing the data

# %% [markdown]
# ### SQLite Database

# %%
column_mapping_aenc = {
    # Bonus_AenC
    "emp_id": "EmployeeID",
    "bonus_date": "BonusDate",
    "bonus_amount": "BonusAmount",

    # Customer_AenC
    "id": "CustomerID",
    "fname": "FirstName",
    "lname": "LastName",
    "address": "StreetAddress",
    "city": "City",
    "state": "State",
    "zip": "ZipCode",
    "phone": "PhoneNumber",
    "company_name": "CompanyName",

    # Department_AenC
    "dept_id": "DepartmentID",
    "dept_name": "DepartmentName",
    "dept_head_id": "DepartmentHeadID",

    # Employee_AenC
    "emp_id": "EmployeeID",
    "manager_id": "ManagerID",
    "emp_fname": "FirstName",
    "emp_lname": "LastName",
    "dept_id": "DepartmentID",
    "street": "StreetAddress",
    "city": "City",
    "state": "State",
    "zip_code": "ZipCode",
    "phone": "PhoneNumber",
    "status": "EmploymentStatus",
    "ss_number": "SSN",
    "salary": "Salary",
    "start_date": "StartDate",
    "birth_date": "BirthDate",
    "bene_health_ins": "HealthInsurance",
    "bene_life_ins": "LifeInsurance",
    "bene_day_care": "DayCareBenefit",
    "sex": "Gender",

    # Product_AenC
    "id": "ProductID",
    "name": "ProductName",
    "description": "ProductDescription",
    "prod_size": "ProductSize",
    "color": "ProductColor",
    "quantity": "QuantityInStock",
    "unit_price": "UnitPrice",
    "picture_name": "ProductImage",
    "Category": "CategoryName",

    # Sales_Order_AenC
    "id": "SalesOrderID",
    "cust_id": "CustomerID",
    "order_date": "OrderDate",
    "region": "Region",
    "sales_rep": "EmployeeID",

    # Sales_Order_Item_AenC
    "id": "SalesOrderID",
    "line_id": "OrderLineID",
    "prod_id": "ProductID",
    "quantity": "OrderQuantity",
    "ship_date": "ShippedDate",

    # State_AenC
    "state_id": "StateID",
    "state_name": "StateName",
    "state_capital": "StateCapital",
    "country": "Country",
    "region": "Region"
}

Bonus_AenC.rename(columns=column_mapping_aenc, inplace=True)
Customer_AenC.rename(columns=column_mapping_aenc, inplace=True)
Department_AenC.rename(columns=column_mapping_aenc, inplace=True)
Employee_AenC.rename(columns=column_mapping_aenc, inplace=True)
Product_AenC.rename(columns=column_mapping_aenc, inplace=True)
Sales_Order_AenC.rename(columns=column_mapping_aenc, inplace=True)
Sales_Order_Item_AenC.rename(columns=column_mapping_aenc, inplace=True)
State_AenC.rename(columns=column_mapping_aenc, inplace=True)

# %% [markdown]
# ### AdventureWorks Database

# %%
column_mapping_adventureworks = {
    # HumanResources_Department
    "DepartmentID": "DepartmentID",
    "Name": "DepartmentName",
    "GroupName": "DepartmentGroup",
    "ModifiedDate": "DepartmentModifiedDate",

    # HumanResources_Employee
    "BusinessEntityID": "EmployeeID",
    "NationalIDNumber": "NationalID",
    "LoginID": "LoginID",
    "OrganizationNode": "OrganizationNode",
    "OrganizationLevel": "OrganizationLevel",
    "JobTitle": "JobTitle",
    "BirthDate": "BirthDate",
    "MaritalStatus": "MaritalStatus",
    "Gender": "Gender",
    "HireDate": "HireDate",
    "SalariedFlag": "SalariedFlag",
    "VacationHours": "VacationHours",
    "SickLeaveHours": "SickLeaveHours",
    "CurrentFlag": "CurrentEmployeeFlag",
    "rowguid": "RowGUID",
    "ModifiedDate": "EmployeeModifiedDate",
    "DepartmentID": "DepartmentID",

    # Person_Address
    "AddressID": "AddressID",
    "AddressLine1": "AddressLine1",
    "AddressLine2": "AddressLine2",
    "City": "City",
    "StateProvinceID": "StateProvinceID",
    "PostalCode": "PostalCode",
    "SpatialLocation": "SpatialLocation",
    "rowguid": "RowGUID",
    "ModifiedDate": "AddressModifiedDate",
    "BusinessEntityID": "EmployeeID",

    # Person_Person
    "BusinessEntityID": "EmployeeID",
    "PersonType": "PersonType",
    "NameStyle": "NameStyle",
    "Title": "Title",
    "FirstName": "FirstName",
    "MiddleName": "MiddleName",
    "LastName": "LastName",
    "Suffix": "Suffix",
    "EmailPromotion": "EmailPromotion",
    "rowguid": "RowGUID",
    "ModifiedDate": "PersonModifiedDate",

    # Production_BillOfMaterials
    "BillOfMaterialsID": "BillOfMaterialsID",
    "ProductAssemblyID": "ProductAssemblyID",
    "ComponentID": "ComponentID",
    "StartDate": "StartDate",
    "EndDate": "EndDate",
    "UnitMeasureCode": "UnitMeasureCode",
    "BOMLevel": "BOMLevel",
    "PerAssemblyQty": "PerAssemblyQuantity",
    "ModifiedDate": "BOMModifiedDate",

    # Production_Product
    "ProductID": "ProductID",
    "Name": "ProductName",
    "ProductNumber": "ProductNumber",
    "MakeFlag": "MakeFlag",
    "FinishedGoodsFlag": "FinishedGoodsFlag",
    "Color": "ProductColor",
    "SafetyStockLevel": "SafetyStockLevel",
    "ReorderPoint": "ReorderPoint",
    "StandardCost": "StandardCost",
    "ListPrice": "ListPrice",
    "SellStartDate": "SellStartDate",
    "SellEndDate": "SellEndDate",
    "DiscontinuedDate": "DiscontinuedDate",
    "RowGUID": "RowGUID",
    "ProductCategoryID": "ProductCategoryID",
    "ModifiedDate": "ProductModifiedDate",

    # Production_ProductCategory
    "ProductCategoryID": "ProductCategoryID",
    "Name": "CategoryName",
    "RowGUID": "RowGUID",
    "ModifiedDate": "CategoryModifiedDate",

    # Purchasing_PurchaseOrderDetail
    "PurchaseOrderID": "PurchaseOrderID",
    "PurchaseOrderDetailID": "PurchaseOrderDetailID",
    "DueDate": "DueDate",
    "OrderQty": "OrderQuantity",
    "ProductID": "ProductID",
    "UnitPrice": "UnitPrice",
    "LineTotal": "LineTotal",
    "ReceivedQty": "ReceivedQuantity",
    "RejectedQty": "RejectedQuantity",
    "StockedQty": "StockedQuantity",
    "ModifiedDate": "PurchaseOrderDetailModifiedDate",

    # Purchasing_PurchaseOrderHeader
    "PurchaseOrderID": "PurchaseOrderID",
    "RevisionNumber": "RevisionNumber",
    "Status": "OrderStatus",
    "EmployeeID": "EmployeeID",
    "VendorID": "VendorID",
    "ShipMethodID": "ShipMethodID",
    "OrderDate": "OrderDate",
    "ShipDate": "ShippedDate",
    "SubTotal": "SubTotal",
    "TaxAmt": "TaxAmount",
    "Freight": "Freight",
    "TotalDue": "TotalDue",
    "ModifiedDate": "PurchaseOrderHeaderModifiedDate",

    # Purchasing_Vendor
    "BusinessEntityID": "VendorID",
    "AccountNumber": "AccountNumber",
    "Name": "VendorName",
    "CreditRating": "CreditRating",
    "PreferredVendorStatus": "PreferredVendorStatus",
    "ActiveFlag": "ActiveFlag",
    "PurchasingWebServiceURL": "PurchasingWebServiceURL",
    "ModifiedDate": "VendorModifiedDate",

    # Sales_Customer
    "CustomerID": "CustomerID",
    "PersonID": "PersonID",
    "StoreID": "StoreID",
    "TerritoryID": "TerritoryID",
    "AccountNumber": "AccountNumber",
    "RowGUID": "RowGUID",
    "ModifiedDate": "CustomerModifiedDate",

    # Sales_SalesOrderDetail
    "SalesOrderID": "SalesOrderID",
    "SalesOrderDetailID": "SalesOrderDetailID",
    "CarrierTrackingNumber": "CarrierTrackingNumber",
    "OrderQty": "OrderQuantity",
    "ProductID": "ProductID",
    "SpecialOfferID": "SpecialOfferID",
    "UnitPrice": "UnitPrice",
    "UnitPriceDiscount": "UnitPriceDiscount",
    "LineTotal": "LineTotal",
    "RowGUID": "RowGUID",
    "ModifiedDate": "SalesOrderDetailModifiedDate",
    "SalesPersonID": "EmployeeID"
}

HumanResourcesDepartment_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
HumanResourcesEmployee_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
PersonAddress_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
Person_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
ProductionBillOfMaterials_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
Product_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
ProductCategory_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
PurchaseOrderDetail_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
PurchaseOrderHeader_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
Vendor_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
Customer_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
SalesOrderDetail_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
SalesOrderHeader_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
SalesTerritory_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
Store_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)
Sysdiagrams_AdventureWorks.rename(columns=column_mapping_adventureworks, inplace=True)

# %% [markdown]
# ### NorthWind Database

# %%
column_mapping_northwind = {
    # HumanResources_Department
    "DepartmentID": "DepartmentID",
    "Name": "DepartmentName",
    "GroupName": "DepartmentGroup",
    "ModifiedDate": "DepartmentModifiedDate",

    # HumanResources_Employee
    "BusinessEntityID": "EmployeeID",
    "NationalIDNumber": "NationalID",
    "LoginID": "LoginID",
    "OrganizationNode": "OrganizationNode",
    "OrganizationLevel": "OrganizationLevel",
    "JobTitle": "JobTitle",
    "BirthDate": "BirthDate",
    "MaritalStatus": "MaritalStatus",
    "Gender": "Gender",
    "HireDate": "HireDate",
    "SalariedFlag": "SalariedFlag",
    "VacationHours": "VacationHours",
    "SickLeaveHours": "SickLeaveHours",
    "CurrentFlag": "CurrentEmployeeFlag",
    "rowguid": "RowGUID",
    "ModifiedDate": "EmployeeModifiedDate",

    # Person_Address
    "AddressID": "AddressID",
    "AddressLine1": "AddressLine1",
    "AddressLine2": "AddressLine2",
    "City": "City",
    "StateProvinceID": "StateProvinceID",
    "PostalCode": "PostalCode",
    "SpatialLocation": "SpatialLocation",
    "BusinessEntityID": "EmployeeID",
    "ModifiedDate": "AddressModifiedDate",

    # Person_Person
    "BusinessEntityID": "EmployeeID",
    "PersonType": "PersonType",
    "NameStyle": "NameStyle",
    "Title": "Title",
    "FirstName": "FirstName",
    "MiddleName": "MiddleName",
    "LastName": "LastName",
    "Suffix": "Suffix",
    "EmailPromotion": "EmailPromotion",
    "rowguid": "RowGUID",
    "ModifiedDate": "PersonModifiedDate",

    # Production_BillOfMaterials
    "BillOfMaterialsID": "BillOfMaterialsID",
    "ProductAssemblyID": "ProductAssemblyID",
    "ComponentID": "ComponentID",
    "StartDate": "StartDate",
    "EndDate": "EndDate",
    "UnitMeasureCode": "UnitMeasureCode",
    "BOMLevel": "BOMLevel",
    "PerAssemblyQty": "PerAssemblyQuantity",
    "ModifiedDate": "BOMModifiedDate",

    # Production_Product
    "ProductID": "ProductID",
    "Name": "ProductName",
    "ProductNumber": "ProductNumber",
    "MakeFlag": "MakeFlag",
    "FinishedGoodsFlag": "FinishedGoodsFlag",
    "Color": "ProductColor",
    "SafetyStockLevel": "SafetyStockLevel",
    "ReorderPoint": "ReorderPoint",
    "StandardCost": "StandardCost",
    "ListPrice": "ListPrice",
    "SellStartDate": "SellStartDate",
    "SellEndDate": "SellEndDate",
    "DiscontinuedDate": "DiscontinuedDate",
    "RowGUID": "RowGUID",
    "ProductCategoryID": "ProductCategoryID",
    "ModifiedDate": "ProductModifiedDate",

    # Production_ProductCategory
    "ProductCategoryID": "ProductCategoryID",
    "Name": "CategoryName",
    "RowGUID": "RowGUID",
    "ModifiedDate": "CategoryModifiedDate",

    # Purchasing_PurchaseOrderDetail
    "PurchaseOrderID": "PurchaseOrderID",
    "PurchaseOrderDetailID": "PurchaseOrderDetailID",
    "DueDate": "DueDate",
    "OrderQty": "OrderQuantity",
    "ProductID": "ProductID",
    "UnitPrice": "UnitPrice",
    "LineTotal": "LineTotal",
    "ReceivedQty": "ReceivedQuantity",
    "RejectedQty": "RejectedQuantity",
    "StockedQty": "StockedQuantity",
    "ModifiedDate": "PurchaseOrderDetailModifiedDate",

    # Purchasing_PurchaseOrderHeader
    "PurchaseOrderID": "PurchaseOrderID",
    "RevisionNumber": "RevisionNumber",
    "Status": "OrderStatus",
    "EmployeeID": "EmployeeID",
    "VendorID": "VendorID",
    "ShipMethodID": "ShipMethodID",
    "OrderDate": "OrderDate",
    "ShipDate": "ShippedDate",
    "SubTotal": "SubTotal",
    "TaxAmt": "TaxAmount",
    "Freight": "Freight",
    "TotalDue": "TotalDue",
    "ModifiedDate": "PurchaseOrderHeaderModifiedDate",

    # Purchasing_Vendor
    "BusinessEntityID": "VendorID",
    "AccountNumber": "AccountNumber",
    "Name": "VendorName",
    "CreditRating": "CreditRating",
    "PreferredVendorStatus": "PreferredVendorStatus",
    "ActiveFlag": "ActiveFlag",
    "PurchasingWebServiceURL": "PurchasingWebServiceURL",
    "ModifiedDate": "VendorModifiedDate",

    # Sales_Customer
    "CustomerID": "CustomerID",
    "PersonID": "PersonID",
    "StoreID": "StoreID",
    "TerritoryID": "TerritoryID",
    "AccountNumber": "AccountNumber",
    "RowGUID": "RowGUID",
    "ModifiedDate": "CustomerModifiedDate",

    # Sales_SalesOrderDetail
    "OrderID": "SalesOrderID",
    "SalesOrderDetailID": "SalesOrderDetailID",
    "CarrierTrackingNumber": "CarrierTrackingNumber",
    "Quantity": "OrderQuantity",
    "ProductID": "ProductID",
    "SpecialOfferID": "SpecialOfferID",
    "UnitPrice": "UnitPrice",
    "UnitPriceDiscount": "UnitPriceDiscount",
    "LineTotal": "LineTotal",
    "RowGUID": "RowGUID",
    "ModifiedDate": "SalesOrderDetailModifiedDate"
}

Categories_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
CustomerCustomerDemo_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
CustomerDemographics_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Customers_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
EmployeeTerritories_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Employees_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
OrderDetails_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Orders_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Products_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Region_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Shippers_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Suppliers_NorthWind.rename(columns=column_mapping_northwind, inplace=True)
Territories_NorthWind.rename(columns=column_mapping_northwind, inplace=True)

# %% [markdown]
# # Product

# %% [markdown]
# # SalesOrderDetails

# %%
# 'OrderHeader' en 'OrderDetails' dataframes per database mergen
df1 = Sales_Order_AenC.merge(Sales_Order_Item_AenC, how='left', on='SalesOrderID')
df2 = SalesOrderHeader_AdventureWorks.merge(SalesOrderDetail_AdventureWorks, left_on='SalesOrderID', right_on='SalesOrderDetailID')
df3 = Orders_NorthWind.merge(OrderDetails_NorthWind, how='left', on='SalesOrderID')

# Aanmaak van de complete dataframe
df = pd.concat([df1, df2, df3], join='outer')

# Drop onnodige columns
df = df.drop(
[  
'Region','RevisionNumber','OnlineOrderFlag','SalesOrderNumber','BillToAddressID', 
'ShipToAddressID','ShipMethodID', 'CreditCardID', 'CreditCardApprovalCode',   
'Comment', 'RowGUID_x', 'SalesOrderDetailModifiedDate_x','SalesOrderDetailID', 
'SpecialOfferID',  'UnitPriceDiscount','RowGUID_y', 'SalesOrderDetailModifiedDate_y', 
'ShipVia',  'ShipAddress', 'ShipCity', 'ShipRegion','ShipPostalCode', 'ShipCountry'
], axis=1)

# Combineer de 'SalesOrderID' columns
df['SalesOrderID'] = df['SalesOrderID_x'].combine_first(df['SalesOrderID_y']).combine_first(df['SalesOrderID'])
df.drop(['SalesOrderID_x','SalesOrderID_y'], axis=1, inplace=True)
df

# [
# 'SalesOrderID','SalesOrderID_x','SalesOrderID_y','PurchaseOrderNumber','EmployeeID','TerritoryID',
# 'CustomerID','AccountNumber','ProductID','OrderDate','ShippedDate','OrderStatus','CurrencyRateID',
# 'Freight','OrderQuantity','OrderLineID','LineTotal','UnitPrice','SubTotal','TaxAmount','Discount',
# 'TotalDue','DueDate','ShipName','RequiredDate','CarrierTrackingNumber'
# ]
# Out:
# /tmp/ipykernel_4291/2749067090.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df1, df2, df3], join='outer')
#        SalesOrderID CustomerID          OrderDate EmployeeID  OrderLineID  \
# 0            2001.0        101        14-Mar-2022        299          1.0
# 1            2001.0        101        14-Mar-2022        299          2.0
# 2            2001.0        101        14-Mar-2022        299          3.0
# 3            2002.0        102        18-Mar-2022        467          1.0
# 4            2002.0        102        18-Mar-2022        467          2.0
# ...             ...        ...                ...        ...          ...
# 31460       75119.0      11981  06/30/24 00:00:00        280          NaN
# ...

# %% [markdown]
# # Upload the data to the PostgreSQL database

# %%
engine2 = create_engine(f"postgresql://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_dbname}")

df.to_sql('SalesOrderDetails', engine2, if_exists='replace', index=False)
# Out:
# 568
