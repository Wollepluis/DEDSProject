# %%
import pandas as pd
import pyodbc
from sqlalchemy import create_engine

# Pad naar je Access-database
db_path = r"C:\Users\melle\Downloads\AdventureWorks (1).mdb"

# Verbindingsstring (met SQLAlchemy dialect voor Access)
conn_str = r"access+pyodbc:///?odbc_connect=" + \
           r"DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=" + db_path

# Maak verbinding met de Access-database via SQLAlchemy
conn = create_engine(conn_str)

# %%
import pandas as pd


Person_Person_df = pd.read_sql("SELECT * FROM Person_Person", conn)
HumanResources_Department_df = pd.read_sql("SELECT * FROM HumanResources_Department", conn)
HumanResources_Employee_df = pd.read_sql("SELECT * FROM HumanResources_Employee", conn)
Person_Address_df = pd.read_sql("SELECT * FROM Person_Address", conn)
Production_BillOfMaterials_df = pd.read_sql("SELECT * FROM Production_BillOfMaterials", conn)
Production_Product_df = pd.read_sql("SELECT * FROM Production_Product", conn)
Production_ProductCategory_df = pd.read_sql("SELECT * FROM Production_ProductCategory", conn)
Purchasing_PurchaseOrderDetail_df = pd.read_sql("SELECT * FROM Purchasing_PurchaseOrderDetail", conn)
Purchasing_PurchaseOrderHeader_df = pd.read_sql("SELECT * FROM Purchasing_PurchaseOrderHeader", conn)
Purchasing_Vendor_df = pd.read_sql("SELECT * FROM Purchasing_Vendor", conn)
Sales_Customer_df = pd.read_sql("SELECT * FROM Sales_Customer", conn)
Sales_SalesOrderDetail_df = pd.read_sql("SELECT * FROM Sales_SalesOrderDetail", conn)
Sales_SalesOrderHeader_df = pd.read_sql("SELECT * FROM Sales_SalesOrderHeader", conn)
Sales_SalesTerritory_df = pd.read_sql("SELECT * FROM Sales_SalesTerritory", conn)
Sales_Store_df = pd.read_sql("SELECT * FROM Sales_Store", conn)

# %%
HumanResources_Department_df
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
#
#                                GroupName ModifiedDate
# 0               Research and Development   2018-04-30
# 1               Research and Development   2018-04-30
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib

# Databaseverbinding instellen (zonder wachtwoord, met Windows Authentication)
server = 'LAPTOP_MELLE\SQLEXPRESS'  # Bijvoorbeeld: 'DESKTOP-ABC123\SQLEXPRESS'
database = 'NorthWind'

# Maak de connection string voor Windows Authentication
connection_string = f"DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};DATABASE={database};Trusted_Connection=yes"
connection_uri = f"mssql+pyodbc:///?odbc_connect={urllib.parse.quote_plus(connection_string)}"

# Maak de engine aan
engine = create_engine(connection_uri)

# Gebruik de engine als conn in je code
conn = engine.connect()

# %%
import pandas as pd

Categories_df            = pd.read_sql("SELECT * FROM [Categories]", conn)
CustomerCustomerDemo_df  = pd.read_sql("SELECT * FROM CustomerCustomerDemo", conn)
CustomerDemographics_df  = pd.read_sql("SELECT * FROM CustomerDemographics", conn)
Customers_df             = pd.read_sql("SELECT * FROM Customers", conn)
EmployeeTerritories_df   = pd.read_sql("SELECT * FROM EmployeeTerritories", conn)
Employees_df             = pd.read_sql("SELECT * FROM Employees", conn)
Order_Details_df         = pd.read_sql("SELECT * FROM [Order Details]", conn)
Orders_df                = pd.read_sql("SELECT * FROM Orders", conn)
Products_df              = pd.read_sql("SELECT * FROM Products", conn)
Region_df                = pd.read_sql("SELECT * FROM Region", conn)
Shippers_df              = pd.read_sql("SELECT * FROM Shippers", conn)
Suppliers_df             = pd.read_sql("SELECT * FROM Suppliers", conn)
Territories_df           = pd.read_sql("SELECT * FROM Territories", conn)

# %%
EmployeeTerritories_df
# Out:
#     EmployeeID TerritoryID
# 0            1       06897
# 1            1       19713
# 2            2       01581
# 3            2       01730
# 4            2       01833
# 5            2       02116
# 6            2       02139
# 7            2       02184
# 8            2       40222
# 9            3       30346
# 10           3       31406
# 11           3       32859
# 12           3       33607
# 13           4       20852
# 14           4       27403
# 15           4       27511
# 16           5       02903
# 17           5       07960
# 18           5       08837
# 19           5       10019
# 20           5       10038
# 21           5       11747
# 22           5       14450
# 23           6       85014
# 24           6       85251
# 25           6       98004
# 26           6       98052
# 27           6       98104
# 28           7       60179
# 29           7       60601
# 30           7       80202
# 31           7       80909
# 32           7       90405
# ...

# %%
# Out:
#     SupplierID                             CompanyName  \
# 0            1                          Exotic Liquids
# 1            2              New Orleans Cajun Delights
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# 5            6                                Mayumi's
# 6            7                           Pavlova, Ltd.
# 7            8                Specialty Biscuits, Ltd.
# 8            9                        PB Knäckebröd AB
# 9           10               Refrescos Americanas LTDA
# 10          11             Heli Süßwaren GmbH & Co. KG
# 11          12       Plutzer Lebensmittelgroßmärkte AG
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13          14                 Formaggi Fortini s.r.l.
# 14          15                         Norske Meierier
# 15          16                       Bigfoot Breweries
# ...

# %%
import sqlite3

# Connect to database (or create if it doesn't exist)
connection = sqlite3.connect(r"C:\Users\melle\Downloads\aenc (1).sqlite")  # Replace with your database file

# Create a cursor object

# %%
Bonus = pd.read_sql("SELECT * FROM Bonus", connection)
Customer = pd.read_sql("SELECT * FROM Customer", connection)
Department = pd.read_sql("SELECT * FROM Department", connection)
Employee = pd.read_sql("SELECT * FROM Employee", connection)
Product = pd.read_sql("SELECT * FROM Product", connection)
Sales_Order = pd.read_sql("SELECT * FROM Sales_Order", connection)
Sales_Order_Item = pd.read_sql("SELECT * FROM Sales_Order_Item", connection)
State = pd.read_sql("SELECT * FROM State", connection)

# %%
Department
# Out:
#    dept_id  dept_name  dept_head_id
# 0      100      R & D           501
# 1      200      Sales           902
# 2      300    Finance          1293
# 3      400  Marketing          1576
# 4      500   Shipping           703

# %%
Address_df = pd.DataFrame(columns=[
    'AddressID', 'AddressLine1', 'Country', 'StateName', 
    'StateCapital', 'Region', 'PostalCode', 'SpatialLocation', 'City'
])

# %%
Customer_Address = Customers_df.rename({'Address' : 'AddressLine1'}, inplace=True)
Customer_Address = Customer_Address.drop(columns=['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'PostalCode', 'Phone', 'Fax'])
Address_df = pd.concat([Address_df, Customer_Address], ignore_index=True)
Customer_Address.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 2
#       1 Customer_Address = Customers_df.rename({'Address' : 'AddressLine1'}, inplace=True)
# ----> 2 Customer_Address = Customer_Address.drop(columns=['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'PostalCode', 'Phone', 'Fax'])
#       3 Address_df = pd.concat([Address_df, Customer_Address], ignore_index=True)
#       4 Customer_Address.columns
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
Customers_df.columns

nieuw_Customers_df = Customers_df.rename(columns={'ContactName' : 'FullName', 'Address' : 'AddressID', 'ContactTitle' : 'Title'})
# Out:
# Index(['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax'],
#       dtype='object')

# %%
Sales_Customer_df.columns
Nieuw_Customer_df = Sales_Customer_df.rename()
# Out:
# Index(['CustomerID', 'PersonID', 'StoreID', 'TerritoryID', 'AccountNumber',
#        'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
Customer.columns
Customer.rename(columns={'id' : 'CustomerID'})
Customer['FullName'] = Customer['fname'] + ' ' + Customer['lname']
# Out:
# Index(['id', 'fname', 'lname', 'address', 'city', 'state', 'zip', 'phone',
#        'company_name'],
#       dtype='object')

# %%
Employees_df.columns.rename(columns={'BusinessEntityID' : 'EmployeeID'})
# Out:
# Index(['EmployeeID', 'LastName', 'FirstName', 'Title', 'TitleOfCourtesy',
#        'BirthDate', 'HireDate', 'Address', 'City', 'Region', 'PostalCode',
#        'Country', 'HomePhone', 'Extension', 'Photo', 'Notes', 'ReportsTo',
#        'PhotoPath'],
#       dtype='object')

# %%
HumanResources_Employee_df.rename(columns={'BusinessEntityID' : 'EmployeeID'})
